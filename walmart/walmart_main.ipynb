# %%
import pandas as pd
import numpy as np

# %%
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from time import sleep

def web_spider(max_page):
    driver = webdriver.Chrome('/Users/Chris/Downloads/chromedriver')
    page = 1
    url = 'https://www.walmart.com/reviews/product/54742302'
    driver.get(url)

    titles_data = []
    dates_data = []
    yn_data = []
    reviews_data = []
    while page < max_page:
        
        if page in [1,2,3,4]:
            driver.find_element_by_xpath('//*[@id="CustomerReviews-container"]/div[1]/div[3]/div/div[1]/ul/li['+str(page)+']/button').click()
        elif page ==35:
            driver.find_element_by_xpath('//*[@id="CustomerReviews-container"]/div[1]/div[3]/div/div[1]/ul/li[6]/button').click()
        elif page ==36:
            driver.find_element_by_xpath('//*[@id="CustomerReviews-container"]/div[1]/div[3]/div/div[1]/ul/li[7]/button').click()
        else:
            driver.find_element_by_xpath('//*[@id="CustomerReviews-container"]/div[1]/div[3]/div/div[1]/ul/li[5]/button').click()
        
        sleep(3)

        html = driver.page_source
        soup = BeautifulSoup(html, 'html.parser')

        titles = soup.findAll('div', attrs={'class': 'review-title'})
        dates = soup.findAll('div', attrs={'class':'review-submissionTime text-right'})
        numYesNo = soup.findAll('span', attrs={'class':'font-normal'})
        reviewsObj = soup.find_all('div', attrs={'class':'zeus-collapsable clearfix'}, string=True)

        tempTitle = [elem.text for elem in titles]
        tempDate = [elem.text for elem in dates]
        tempLike = [elem.text for elem in numYesNo]
        tempReview = [elem.text for elem in reviewsObj]

        titles_data.append(tempTitle)
        dates_data.append(tempDate)
        yn_data.append(tempLike)
        reviews_data.append(tempReview)

        # move to next page
        page += 1
        #driver.implicitly_wait(7)
        
        sleep(7)

    driver.close()

    return [titles_data,dates_data,yn_data,reviews_data]

# %%
walmart_scrap = web_spider(37)

# %%
titles = sum([*walmart_scrap[0]],[])
dates = sum([*walmart_scrap[1]],[])
likes = sum([*walmart_scrap[2]],[])
reviews = sum([*walmart_scrap[3]],[])

# %%
like_data = []
for i in range(len(likes)):
    if i%4 == 2:
        pass
    else:
        like_data.append(likes[i])
        
final_like_data = []
for i in range(len(like_data)):
    if i%3 == 2:
        pass
    else:
        final_like_data.append(like_data[i])
        
yes = []
no = []
for i in range(len(final_like_data)):
    if i%2 == 0:
        yes.append(final_like_data[i])
    else:
        no.append(final_like_data[i])

# %%
walmartTable = [('title', titles),
               ('review', reviews),
               ('date', dates),
               ('yes', yes),
               ('no', no)]

walmartDF = pd.DataFrame.from_items(walmartTable)
walmartDF
# Out:
#                                                 title  \
# 0        Google making hardware is a beautiful thing.
# 1       Google Home is a great product for the family
# 2          The Google Home Makes Life More Convenient
# 3                                  Google Home is fun
# 4                           This thing is pretty cool
# 5                   Google Home VERSUS Amazon's Echo!
# 6    Google Home has a long way to catch up to Alexa.
# 7               Great Sound. Great Price. Go Google!!
# 8       Don't know what I'd do without my Google Home
# 9                       Have had for a year now, LOVE
# 10              Still waiting for some needed updates
# 11          Amazon echo blows this away. I have both.
# 12                 Very Good, with Only a Few Hiccups
# 13                              Google Home Assistant
# 14                                       Side by side
# 15               Can't imagine life without this now!
# 16                          Does less than advertised
# 17                             Google Home is AMAZING
# 18                      Smartest Member of my Family!
# 19         GH: The Best Voice Assistant on the Market
# 20           Such wonderful stereo from a Little Item
# 21                       Microphone needs improvement
# 22                       I wish i could rate it lower
# 23               Best darn thing, since sliced bread.
# 24                                        Works great
# 25                               Google Home Purchase
# 26                     Let down by the music feature!
# 27                                        Google Home
# 28                                  Makes life easier
# 29                                Excellent Assistant
# ..                                                ...
# 689                      Nice, better than I expected
# 690                                               Yay
# 691                                     Great product
# 692                                       Educational
# 693                                     great product
# 694                                       Google Home
# 695                                              Home
# 696                                    Christmas gift
# 697                                        Great gift
# 698                                               Dan
# 699                                Great sound system
# 700                                   Arrived quickly
# 701                                       Goggle home
# 702      Very nice product. Waiting on more upgrades.
# 703                   "The future if home automation"
# 704               Great product.  Great shipping time
# 705                                      LOTS OF BASS
# 706                                           Awesome
# 707                                       google home
# 708    Awfully good device--- easy to use by all ages
# 709                                    Great Product!
# 710                                            Great!
# 711                           This device is Amazing!
# 712                                        Great Item
# 713                                         Excellent
# 714                                        Great Item
# 715                                             Happy
# 716                                          Love it!
# 717                                     life changing
# 718                                           love it
#
#                                                 review        date     yes  \
# 0    Amazing product. The accuracy recognizing what...  11/20/2016   (957)
# 1    I’ve had my Google Home for about 3 weeks and ...  11/26/2016  (1325)
# 2    The Google Home is a well built voice activate...   11/6/2016   (932)
# 3    I ordered this because I had seen it advertise...  12/15/2016   (428)
# 4    It's pretty much like having the power of the ...   11/5/2016   (473)
# 5    I think that Amazon's ECHO (Alexa) need a bit ...   10/8/2016   (563)
# 6    Google Home has a long way to catch up to Alex...   12/6/2017    (77)
# 7    We love our Google Home and regularly use it a...    2/8/2018     (6)
# 8    I don't know what I did without my google home...  12/14/2017    (77)
# 9    I have had Google Home for 1 year now. I liked...  12/27/2017    (18)
# 10   So far my Google Home (GH) experience has been...  12/11/2016   (129)
# 11   I never seen Google deliver a product that was...  12/29/2016    (95)
# 12   I really like the Google Home. If you've thoug...   1/23/2017    (75)
# 13   Fine example of AI (Artificial Intelligence). ...    3/4/2017   (114)
# 14   The Google Home sits beside my Amazon Echo.  I...   12/6/2016   (126)
# 15   I'm far more impressed than expected. Having b...  11/15/2016   (521)
# 16   Though the Google Home is great for answering ...   9/11/2017    (60)
# 17   I purchased this product during the $99 promot...  11/28/2016   (145)
# 18   It is easy to set up.   Connect it to your wir...   1/10/2017    (19)
# 19   The decision was simple for me, GOOGLE ASSISTA...   12/8/2016    (92)
# 20   I get Google Music which includes commercial f...   10/1/2017    (79)
# 21   The microphone is useless when the speaker vol...   3/29/2018     (0)
# 22   I wish i could give it lower that one star. Th...   12/3/2017    (76)
# 23   I took a chance buying this device, because I ...  12/10/2016    (40)
# 24              Arrived on time. And works as expected   3/23/2018     (0)
# 25   I bought this product and I am so happy and ex...  11/29/2016    (68)
# 26   I chose the Google Home over Amazon's Echo due...   1/10/2017     (7)
# 27   A welcome addition to our smart home.So much m...   12/7/2017     (5)
# 28   Still getting used to Google Home but enjoying...   2/27/2018     (0)
# 29   I was on the fence between this and the Amazon...   12/6/2016    (40)
# ..                                                 ...         ...     ...
# 689                Great fun,  every day learning more  12/18/2016     (0)
# 690                                Love my google home  12/25/2016     (0)
# 691  Will get better in time as Google updates soft...  12/10/2016     (0)
# 692     Great for children to ask questions and learn.  12/11/2016     (0)
# 693                                  it work excellent  12/22/2016     (0)
# 694  Love it and the sound is great! Got it on sale...   12/7/2016     (0)
# 695            Lots of fun. Will add accessories soon.  12/11/2016     (0)
# 696                          It's a gift for my sister  12/17/2016     (0)
# 697                A nice gift for anyone on your list  12/12/2016     (0)
# 698                                    My son loves it  12/20/2016     (0)
# 699            Great sound  system over youtube music.   12/9/2016     (0)
# 700                   Going to be fun for whole family  12/10/2016     (0)
# 701                   Doesn't do as much as I  thought  12/10/2016     (0)
# 702                            Can't beat the price!!!  12/14/2016     (0)
# 703                  Will definity enjoy this product.   12/7/2016     (0)
# 704                        Awesome service and product   12/9/2016     (0)
# 705                        NICE SIZE WITH ALOT OF BASS   12/9/2016     (0)
# 706                      Great gift for a tech person.   12/8/2016     (0)
# 707                       easy to set up. easy to use.   12/8/2016     (0)
# 708                                              By it  12/18/2016     (0)
# 709                                   Worth the money.  12/12/2016     (0)
# 710                        I like it better than Alexa   12/7/2016     (0)
# 711                            This device is amazing!   12/8/2016     (0)
# 712                                            Love it  12/15/2016     (0)
# 713                                          Excellent  12/13/2016     (0)
# 714                                         Great Item  12/12/2016     (0)
# 715                                       Great sound.   12/9/2016     (0)
# 716                                              Nice.  12/12/2016     (0)
# 717                                       kids love it   12/8/2016     (0)
# 718                                            Love it   12/9/2016     (0)
#
#         no
# 0    (412)
# 1    (322)
# 2    (296)
# 3    (264)
# 4    (258)
# 5    (790)
# 6     (79)
# 7      (3)
# 8     (60)
# 9      (4)
# 10    (91)
# 11    (41)
# 12    (41)
# 13   (107)
# 14    (43)
# 15    (59)
# 16    (18)
# 17    (35)
# 18     (5)
# 19    (26)
# 20    (52)
# 21     (0)
# 22    (64)
# 23     (4)
# 24     (0)
# 25    (17)
# 26     (1)
# 27     (1)
# 28     (0)
# 29     (6)
# ..     ...
# 689    (0)
# 690    (0)
# 691    (0)
# 692    (0)
# 693    (0)
# 694    (0)
# 695    (0)
# 696    (0)
# 697    (0)
# 698    (0)
# 699    (0)
# 700    (0)
# 701    (0)
# 702    (0)
# 703    (0)
# 704    (0)
# 705    (0)
# 706    (0)
# 707    (0)
# 708    (0)
# 709    (0)
# 710    (0)
# 711    (0)
# 712    (0)
# 713    (0)
# 714    (0)
# 715    (0)
# 716    (0)
# 717    (0)
# 718    (0)
#
# [719 rows x 5 columns]

# %%
walmartDF.to_csv('walmartDF.csv')

# %%
len(set(reviews))
# Out:
# 714
